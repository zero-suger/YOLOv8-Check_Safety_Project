# %% [markdown]
# **Checking** ` GPU`

# %%
# !nvidia-smi
# Out:
# Tue May 23 12:49:09 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# **Installing YOLOv8** : `pip install ultralytics`
#
# Yolov8 supports : **Modes** (`Train, Test and Validation`) and **Tasks** (`detect, segment, classify`)

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 589.4/589.4 kB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.5/206.5 kB 28.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# # **Predicting** the `object` with Model `yolov8n.pt`

# %%
# !yolo predict model = yolov8n.pt source = '/content/YOLO_image_test.jpeg'
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# image 1/1 /content/YOLO_image_test.jpeg: 288x640 4 cars, 57.6ms
# Speed: 1.7ms preprocess, 57.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %% [markdown]
# **Note : Google Colab can't support with internal source PATH and WebCam model.**

# %% [markdown]
# ![831e8119-812b-402d-abec-bd2a4739686a.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Detecting** the `object` with Model `yolov8s.pt`

# %%
# !yolo task = detect predict model = yolov8s.pt source = '/content/YOLO_image_test.jpeg'
# Out:
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients
#
# image 1/1 /content/YOLO_image_test.jpeg: 288x640 4 cars, 1 bench, 101.6ms
# Speed: 2.0ms preprocess, 101.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4

# %% [markdown]
# For `task = detect`, **yolov8s.pt** model is used and detect new object `bench = 0.28 `

# %% [markdown]
# ![01.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Segmentation** the `object` with Model `YOLOv8n-seg`

# %%
# !yolo task = segment predict model = yolov8n-seg.pt source = '/content/YOLO_image_test.jpeg'
# Out:
# ...
# 100% 6.73M/6.73M [00:00<00:00, 11.8MB/s]
# Ultralytics YOLOv8.0.107 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients
#
# image 1/1 /content/YOLO_image_test.jpeg: 288x640 8 cars, 1 stop sign, 95.2ms
# Speed: 2.5ms preprocess, 95.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict

# %% [markdown]
# For `task = segment`, `yolov8n-seg.pt` model is used.

# %% [markdown]
# ![02.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # use the YOLOv8 with **Python Script**

# %%
from ultralytics import YOLO

# Load the detection model

model = YOLO('yolov8n.pt')

# predict the object by using the model

model.predict(source = '/content/YOLO_image_test.jpeg')
# Out:
# image 1/1 /content/YOLO_image_test.jpeg: 288x640 4 cars, 62.7ms
# Speed: 2.3ms preprocess, 62.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
# ...
